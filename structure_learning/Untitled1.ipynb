# %%
import pandas as pd

# %%
an = pd.read_csv('./anisio_WQOLFisico.csv')

# %%
an
# Out:
#         WHOQoL_1  WHOQoL_2  WHOQoL_3  WHOQoL_4  WHOQoL_5  WHOQoL_6  WHOQoL_7  \
# 0            4.0       4.0       1.0       1.0       4.0       5.0       4.0
# 1            2.0       4.0       3.0       2.0       3.0       4.0       3.0
# 2            5.0       4.0       1.0       1.0       3.0       3.0       3.0
# 3            4.0       3.0       2.0       3.0       3.0       4.0       3.0
# 4            2.0       2.0       3.0       3.0       2.0       4.0       3.0
# ...          ...       ...       ...       ...       ...       ...       ...
# 148412       4.0       3.0       1.0       2.0       2.0       2.0       3.0
# 148413       3.0       3.0       2.0       2.0       3.0       4.0       2.0
# 148414       2.0       2.0       4.0       3.0       2.0       2.0       3.0
# 148415       1.0       1.0       2.0       1.0       4.0       4.0       5.0
# 148416       4.0       5.0       1.0       2.0       4.0       4.0       4.0
#
# ...

# %%
an.to_csv('./anisio_WQOLFisico2.csv', index=False, sep=' ', header=False)

# %%
import numpy as np

# %%
pd.DataFrame(np.zeros((26,26))).to_csv('./an_net.txt', index=False, sep=',', header=False)

# %%
an = pd.read_csv('./anisio_WQOLFisico2.csv')

# %%
an
# Out:
#        4.0\t4.0\t1.0\t1.0\t4.0\t5.0\t4.0\t4.0\t4.0\t4.0\t3.0\t3.0\t3.0\t4.0\t4.0\t4.0\t4.0\t4.0\t4.0\t4.0\t4.0\t4.0\t4.0\t4.0\t1.0\t4.285714285714286
# 0       2.0\t4.0\t3.0\t2.0\t3.0\t4.0\t3.0\t2.0\t4.0\t3...
# 1       5.0\t4.0\t1.0\t1.0\t3.0\t3.0\t3.0\t4.0\t5.0\t4...
# 2       4.0\t3.0\t2.0\t3.0\t3.0\t4.0\t3.0\t3.0\t2.0\t3...
# 3       2.0\t2.0\t3.0\t3.0\t2.0\t4.0\t3.0\t3.0\t3.0\t3...
# 4       5.0\t5.0\t3.0\t2.0\t4.0\t4.0\t3.0\t4.0\t4.0\t4...
# ...                                                   ...
# 148411  4.0\t3.0\t1.0\t2.0\t2.0\t2.0\t3.0\t2.0\t4.0\t3...
# 148412  3.0\t3.0\t2.0\t2.0\t3.0\t4.0\t2.0\t3.0\t2.0\t3...
# 148413  2.0\t2.0\t4.0\t3.0\t2.0\t2.0\t3.0\t3.0\t4.0\t1...
# 148414  1.0\t1.0\t2.0\t1.0\t4.0\t4.0\t5.0\t5.0\t5.0\t4...
# 148415  4.0\t5.0\t1.0\t2.0\t4.0\t4.0\t4.0\t4.0\t3.0\t5...
#
# [148416 rows x 1 columns]
